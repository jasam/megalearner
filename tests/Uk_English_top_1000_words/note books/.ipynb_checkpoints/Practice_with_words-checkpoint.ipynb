# %%
from IPython.display import Image
from IPython.display import Audio
from random import sample
import pandas as pd

#Read data
file_name = "E:/repos_git/megalearner/tests/google-10000-english/master_words_rules.csv"
words_df = pd.read_csv(file_name, names=["word", "mean", "phonetic", "rule", "path_mp3", "image_path"])

# %%
#Types
words_df.dtypes
# Out:
# word          object
# mean          object
# phonetic      object
# rule          object
# path_mp3      object
# image_path    object
# dtype: object

# %%
#select columns
words_df[["word", "phonetic"]]
# Out:
#                 word           phonetic
# 0            project         ˈprɑdʒˌɛkt
# 1            project         ˈprɑdʒˌɛkt
# 2            mission             ˈmɪʃən
# 3             miller             ˈmɪlər
# 4           accident          ˈæksədənt
# 5              hotel            hoʊˈtɛl
# 6              hotel            hoʊˈtɛl
# 7               also             ˈɔlsoʊ
# 8               also             ˈɔlsoʊ
# 9            amenity           əˈmɛnədi
# 10           ranking            ˈræŋkɪŋ
# 11           ranking            ˈræŋkɪŋ
# 12               tin                tɪn
# 13           million            ˈmɪljən
# 14            unless             ənˈlɛs
# 15         applicant          ˈæpləkənt
# 16              belt               bɛlt
# 17              side               saɪd
# 18            happen             ˈhæpən
# 19             saint              seɪnt
# 20             saint              seɪnt
# 21              help               hɛlp
# 22            device            dəˈvaɪs
# 23              coin               kɔɪn
# 24              coin               kɔɪn
# 25         symposium        sɪmˈpoʊziəm
# 26         symposium        sɪmˈpoʊziəm
# 27              four                fɔr
# 28              four                fɔr
# 29           toolbox          ˈtulˌbɑks
# ...              ...                ...
# 10553      kilometer         kəˈlɑmədər
# 10554  certification  ˌsərdɪfɪˈkeɪʃ(ə)n
# 10555  certification  ˌsərdɪfɪˈkeɪʃ(ə)n
# 10556           norm               nɔrm
# 10557           norm               nɔrm
# 10558    corporation    ˌkɔrpəˈreɪʃ(ə)n
# 10559    corporation    ˌkɔrpəˈreɪʃ(ə)n
# 10560    corporation    ˌkɔrpəˈreɪʃ(ə)n
# 10561    corporation    ˌkɔrpəˈreɪʃ(ə)n
# 10562        readily            ˈrɛdəli
# 10563           scan               skæn
# 10564           node               noʊd
# 10565          guest               ɡɛst
# 10566       exposure         ɪkˈspoʊʒər
# 10567       exposure         ɪkˈspoʊʒər
# 10568      violation     ˌvaɪəˈleɪʃ(ə)n
# 10569      violation     ˌvaɪəˈleɪʃ(ə)n
# 10570          tower           ˈtaʊ(ə)r
# 10571            buy                baɪ
# 10572           edit              ˈɛdət
# 10573         rental           ˈrɛn(t)l
# 10574          grant              ɡrænt
# 10575      volunteer         ˌvɑlənˈtɪr
# 10576      volunteer         ˌvɑlənˈtɪr
# 10577      connector          kəˈnɛktər
# 10578        airline           ˈɛrˌlaɪn
# 10579        airline           ˈɛrˌlaɪn
# 10580            gap                ɡæp
# 10581           pack                pæk
# 10582           very              ˈvɛri
#
# [10583 rows x 2 columns]

# %%
#head
words_df.head()

# %%
#tail
words_df.tail()

# %%
# Transpose
words_df.T

# %%
# Order
words_df.sort(["word"], ascending=True)

# %%
# where condition
words_df[words_df.word == "ability"]

# %%
# Where condition with "or"
words_df[words_df["word"].isin(["hard","later"])]

# %%
# Group by with group function: count()
words_df.groupby(['word']).size()
# Out:
# word
# a                2
# abandoned        1
# ability          2
# able             2
# aboriginal       2
# abortion         2
# about            1
# abraham          3
# abroad           1
# absence          1
# absent           1
# absolute         1
# absolutely       1
# absorption       2
# abstract         2
# abuse            1
# ac               2
# academic         6
# academy          1
# accent           2
# accept           4
# acceptable       1
# acceptance       1
# access           6
# accessibility    2
# accessible       1
# accessory        2
# accident         2
# accommodate      3
# accommodation    6
#                 ..
# yahoo            1
# yale             2
# yard             4
# yarn             2
# yea              2
# yeah             1
# year             2
# yearly           1
# yellow           2
# yemen            1
# yen              1
# yes              1
# yesterday        3
# yet              1
# yo               1
# yoga             1
# you              1
# your             2
# yours            2
# yourself         1
# youth            1
# yugoslavia       3
# zambia           1
# zen              1
# zero             2
# zimbabwe         3
# zinc             1
# zip              1
# zone             2
# zoning           2
# dtype: int64

# %%
# Group by with filter over grouped data
grouped = words_df.groupby(['word'])
grouped.filter(lambda x: len(x) > 3)
# Out:
#                word                         mean          phonetic  \
# 0           project        proyecto (masculine)         ˈprɑdʒˌɛkt
# 1           project        proyecto (masculine)         ˈprɑdʒˌɛkt
# 5             hotel           hotel (masculine)            hoʊˈtɛl
# 6             hotel           hotel (masculine)            hoʊˈtɛl
# 10          ranking                          NaN           ˈræŋkɪŋ
# 11          ranking                          NaN           ˈræŋkɪŋ
# 19            saint                          NaN             seɪnt
# 20            saint                          NaN             seɪnt
# 23             coin           moneda (feminine)               kɔɪn
# 24             coin           moneda (feminine)               kɔɪn
# 35             acre            acre (masculine)             ˈeɪkər
# 36             acre            acre (masculine)             ˈeɪkər
# 39            range          ámbito (masculine)             reɪndʒ
# 40            range          ámbito (masculine)             reɪndʒ
# 41           detail         detalle (masculine)            dəˈteɪl
# 42           detail         detalle (masculine)            dəˈteɪl
# 43     organization     organización (feminine)   ˌɔrɡənəˈzeɪʃ(ə)n
# 44     organization     organización (feminine)   ˌɔrɡənəˈzeɪʃ(ə)n
# 45     organization     organización (feminine)   ˌɔrɡənəˈzeɪʃ(ə)n
# 46     organization     organización (feminine)   ˌɔrɡənəˈzeɪʃ(ə)n
# 49            space         espacio (masculine)              speɪs
# 50            space         espacio (masculine)              speɪs
# 75             save                       salvar              seɪv
# 76             save                       salvar              seɪv
# 85          cartoon          chiste (masculine)            kɑrˈtun
# 86          cartoon          chiste (masculine)            kɑrˈtun
# 95          contain                     contener          kənˈteɪn
# 96          contain                     contener          kənˈteɪn
# 100        exchange     intercambio (masculine)        ɪksˈtʃeɪndʒ
# 101        exchange     intercambio (masculine)        ɪksˈtʃeɪndʒ
# ...             ...                          ...               ...
# 10485        report         informe (masculine)            rəˈpɔrt
# 10486        report         informe (masculine)            rəˈpɔrt
# 10493        update                          NaN          ˌəpˈdeɪt
# 10494        update                          NaN          ˌəpˈdeɪt
# 10515         shade           sombra (feminine)               ʃeɪd
# 10516         shade           sombra (feminine)               ʃeɪd
# 10520    automobile           coche (masculine)        ˈɔdəmoʊˌbil
# 10521    automobile           coche (masculine)        ˈɔdəmoʊˌbil
# 10523             j                            J              dʒeɪ
# 10524             j                            J              dʒeɪ
# 10531       process         proceso (masculine)           ˈprɑˌsɛs
# 10532       process         proceso (masculine)           ˈprɑˌsɛs
# 10533        relate                          NaN           rəˈleɪt
# 10534        relate                          NaN           rəˈleɪt
# 10544        enable                          NaN        ɛnˈeɪb(ə)l
# 10545        enable                          NaN        ɛnˈeɪb(ə)l
# 10546        enable                          NaN        ɛnˈeɪb(ə)l
# 10550          stop                          NaN              stɑp
# 10551     implement                  implementar       ˈɪmpləˌmɛnt
# 10552     implement                  implementar       ˈɪmpləˌmɛnt
# 10558   corporation  sociedad (feminine) anónima   ˌkɔrpəˈreɪʃ(ə)n
# 10559   corporation  sociedad (feminine) anónima   ˌkɔrpəˈreɪʃ(ə)n
# 10560   corporation  sociedad (feminine) anónima   ˌkɔrpəˈreɪʃ(ə)n
# 10561   corporation  sociedad (feminine) anónima   ˌkɔrpəˈreɪʃ(ə)n
# 10568     violation        violación (feminine)     ˌvaɪəˈleɪʃ(ə)n
# 10569     violation        violación (feminine)     ˌvaɪəˈleɪʃ(ə)n
# 10575     volunteer                          NaN        ˌvɑlənˈtɪr
# 10576     volunteer                          NaN        ˌvɑlənˈtɪr
# 10578       airline       línea (feminine) aérea          ˈɛrˌlaɪn
# 10579       airline       línea (feminine) aérea          ˈɛrˌlaɪn
#
#                   rule                                           path_mp3  \
# 0       short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 1       short  o : /ɑ/  E:\repos_git\megalearner\tests\google-10000-en...
# 5        long o : /oʊ/  E:\repos_git\megalearner\tests\google-10000-en...
# 6       short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10       short a : /æ/  E:\repos_git\megalearner\tests\google-10000-en...
# 11      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 19       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 20      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 23      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 24      aw sound : /ɔ/  E:\repos_git\megalearner\tests\google-10000-en...
# 35       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 36      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 39       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 40      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 41       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 42      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 43       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 44      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 45      aw sound : /ɔ/  E:\repos_git\megalearner\tests\google-10000-en...
# 46     or sound : /ɔr/  E:\repos_git\megalearner\tests\google-10000-en...
# 49       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 50      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 75       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 76      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 85      short  o : /ɑ/  E:\repos_git\megalearner\tests\google-10000-en...
# 86     ar sound : /ɑr/  E:\repos_git\megalearner\tests\google-10000-en...
# 95       long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 96      short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 100      long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 101     short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# ...                ...                                                ...
# 10485   aw sound : /ɔ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10486  or sound : /ɔr/  E:\repos_git\megalearner\tests\google-10000-en...
# 10493    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10494   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10515    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10516   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10520    long o : /oʊ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10521   aw sound : /ɔ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10523    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10524   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10531   short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10532   short  o : /ɑ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10533    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10534   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10544    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10545   short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10546   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10550   short  o : /ɑ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10551   short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10552   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10558    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10559   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10560   aw sound : /ɔ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10561  or sound : /ɔr/  E:\repos_git\megalearner\tests\google-10000-en...
# 10568    long a : /eɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10569   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10575   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10576   short  o : /ɑ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10578   short  e : /ɛ/  E:\repos_git\megalearner\tests\google-10000-en...
# 10579   short  i : /ɪ/  E:\repos_git\megalearner\tests\google-10000-en...
#
#                                               image_path
# 0      E:\repos_git\megalearner\tests\google-10000-en...
# 1      E:\repos_git\megalearner\tests\google-10000-en...
# 5      E:\repos_git\megalearner\tests\google-10000-en...
# 6      E:\repos_git\megalearner\tests\google-10000-en...
# 10     E:\repos_git\megalearner\tests\google-10000-en...
# 11     E:\repos_git\megalearner\tests\google-10000-en...
# 19     E:\repos_git\megalearner\tests\google-10000-en...
# 20     E:\repos_git\megalearner\tests\google-10000-en...
# 23     E:\repos_git\megalearner\tests\google-10000-en...
# 24     E:\repos_git\megalearner\tests\google-10000-en...
# 35     E:\repos_git\megalearner\tests\google-10000-en...
# 36     E:\repos_git\megalearner\tests\google-10000-en...
# 39     E:\repos_git\megalearner\tests\google-10000-en...
# 40     E:\repos_git\megalearner\tests\google-10000-en...
# 41     E:\repos_git\megalearner\tests\google-10000-en...
# 42     E:\repos_git\megalearner\tests\google-10000-en...
# 43     E:\repos_git\megalearner\tests\google-10000-en...
# 44     E:\repos_git\megalearner\tests\google-10000-en...
# 45     E:\repos_git\megalearner\tests\google-10000-en...
# 46     E:\repos_git\megalearner\tests\google-10000-en...
# 49     E:\repos_git\megalearner\tests\google-10000-en...
# 50     E:\repos_git\megalearner\tests\google-10000-en...
# 75     E:\repos_git\megalearner\tests\google-10000-en...
# 76     E:\repos_git\megalearner\tests\google-10000-en...
# 85     E:\repos_git\megalearner\tests\google-10000-en...
# 86     E:\repos_git\megalearner\tests\google-10000-en...
# 95     E:\repos_git\megalearner\tests\google-10000-en...
# 96     E:\repos_git\megalearner\tests\google-10000-en...
# 100    E:\repos_git\megalearner\tests\google-10000-en...
# 101    E:\repos_git\megalearner\tests\google-10000-en...
# ...                                                  ...
# 10485  E:\repos_git\megalearner\tests\google-10000-en...
# 10486  E:\repos_git\megalearner\tests\google-10000-en...
# 10493  E:\repos_git\megalearner\tests\google-10000-en...
# 10494  E:\repos_git\megalearner\tests\google-10000-en...
# 10515  E:\repos_git\megalearner\tests\google-10000-en...
# 10516  E:\repos_git\megalearner\tests\google-10000-en...
# 10520  E:\repos_git\megalearner\tests\google-10000-en...
# 10521  E:\repos_git\megalearner\tests\google-10000-en...
# 10523  E:\repos_git\megalearner\tests\google-10000-en...
# 10524  E:\repos_git\megalearner\tests\google-10000-en...
# 10531  E:\repos_git\megalearner\tests\google-10000-en...
# 10532  E:\repos_git\megalearner\tests\google-10000-en...
# 10533  E:\repos_git\megalearner\tests\google-10000-en...
# 10534  E:\repos_git\megalearner\tests\google-10000-en...
# 10544  E:\repos_git\megalearner\tests\google-10000-en...
# 10545  E:\repos_git\megalearner\tests\google-10000-en...
# 10546  E:\repos_git\megalearner\tests\google-10000-en...
# 10550  E:\repos_git\megalearner\tests\google-10000-en...
# 10551  E:\repos_git\megalearner\tests\google-10000-en...
# 10552  E:\repos_git\megalearner\tests\google-10000-en...
# 10558  E:\repos_git\megalearner\tests\google-10000-en...
# 10559  E:\repos_git\megalearner\tests\google-10000-en...
# 10560  E:\repos_git\megalearner\tests\google-10000-en...
# 10561  E:\repos_git\megalearner\tests\google-10000-en...
# 10568  E:\repos_git\megalearner\tests\google-10000-en...
# 10569  E:\repos_git\megalearner\tests\google-10000-en...
# 10575  E:\repos_git\megalearner\tests\google-10000-en...
# 10576  E:\repos_git\megalearner\tests\google-10000-en...
# 10578  E:\repos_git\megalearner\tests\google-10000-en...
# 10579  E:\repos_git\megalearner\tests\google-10000-en...
#
# [2838 rows x 6 columns]

# %%
# Study with pre-defined group
from IPython.display import Image
from IPython.display import Audio
sub_df = words_df[words_df["rule"] == "short  o : /ɑ/"]
sub_df = sub_df.reset_index(drop=True)
indx = int(sample(range(len(sub_df)), 1)[0])
path_image = sub_df.image_path[indx]
word = sub_df.word[indx]
phonetic = sub_df.phonetic[indx]
path_sound = sub_df.path_mp3[indx]
#mean = sub_df.mean[indx]
#print(indx)
print(word)
print(phonetic)
#print(path_sound)
#Image(filename = path_image)
sub_df.loc[indx]
Audio(filename = path_sound, autoplay = "autoplay")
# Out:
# barbados
# bɑrˈbeɪˌdoʊs
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%html
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td><img src="E:\repos_git\megalearner\tests\Uk_English_top_1000_words\images\able.png"></td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td><img src="E:\repos_git\megalearner\tests\Uk_English_top_1000_words\images\able.png"></td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
